# %%
import HP
from gensim.models import Word2Vec

model = Word2Vec.load(HP.embedding_file)

# %%
len(model.wv.vocab)
# Out:
# 33880

# %%
list(model.wv.vocab)
# Out:
# ['occpital',
#  'localizer',
#  'localizes',
#  'gag',
#  'shatzki',
#  'clotted',
#  'spiders',
#  'hanging',
#  'woody',
#  'localized',
#  'procainamide',
#  'openes',
#  'zolfran',
#  'miscell',
#  'dialntin',
#  'hypointensities',
#  'osteoblastic',
#  'laculose',
#  'pigment',
#  'admite',
#  'trileptal',
#  'lidocain',
#  'bringing',
#  'wooded',
#  'otomastoiditis',
#  '5qam',
#  'multiorgan',
#  'wednesday',
#  'stereotypical',
#  'scrapes',
#  'alzhiemers',
#  'ffor',
#  'clavicular',
#  'sustaining',
#  'consenting',
#  'scraped',
#  'errors',
#  'semicircular',
#  'cooking',
#  '137mcg',
#  'hallucinating',
#  'shocks',
#  '27f',
#  'cinacalcet',
#  '27m',
#  'pericardiac',
#  'pericardial',
#  'alcolhol',
#  'lmh',
#  'kids',
#  'echodense',
#  'phenelzine',
#  'deferring',
#  'terbinafine',
#  'tracheoplasty',
#  'neurologist',
#  'spotty',
#  'appropriately',
#  'projection',
#  '2300hrs',
#  'lengthen',
#  'steri',
#  'conintue',
#  'dng',
#  'dna',
# ...
